# %%
from facebook_scraper import get_posts, get_page_info

# %%
posts = list(get_posts("MetaAI", pages=10))
posts
# Out:
# []

# %%
for post in posts:
    print(post)

# %%
get_page_info("TransferyPilkarskie")
# Out:
# {}
